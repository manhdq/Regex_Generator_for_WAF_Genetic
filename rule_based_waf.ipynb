# %% [markdown]
# <a href="https://colab.research.google.com/github/manhdqhe153129/Regex_Generator_for_WAF_Genetic/blob/master/rule_based_waf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import package

# %%
import json
import numpy as np
import pandas as pd

# %% [markdown]
# ## Convert access log to readable json file

# %%
def convert_to_json(log_file, save_file):
  requests_list = []

  with open(log_file) as f:
      for json_obj in f:
          request = json.loads(json_obj)
          requests_list.append(request)

  with open(save_file, 'w') as f:
      json.dump(requests_list, f)

convert_to_json("access_fxh.log", "access_log.json")

# %% [markdown]
# ## Load json access log

# %%
with open('access_log.json') as f:
    requests_list = json.load(f)

# %%
len(requests_list)
# Out:
# 445

# %%
accepted_request = []
for req in requests_list:
    if int(req['status']) < 400:
        accepted_request.append(req)

len(accepted_request)
# Out:
# 439

# %%
accepted_request = [req['request']['request'] for req in accepted_request]
len(accepted_request)
# Out:
# 439

# %%
accepted_request = set(accepted_request)
len(accepted_request)
# Out:
# 191

# %%
## Request

# %%
requests = {}

for req in accepted_request:
  request = {}

  # req_content includes method, uri and parameters
  req_content = req.split(" ")
  query = req_content[1].split('?')
  method = req_content[0]
  if method not in requests:
    requests[method] = []
  
  request['uri'] = query[0]
  if len(query) > 1:
    p = {}
    params = query[1].split('&')
    for param in params:
      key_val = param.split('=')
      if len(key_val) == 2:
        key = key_val[0]
        val = key_val[1]
      else:
        key = key_val[0]
        val = None
      p[key] = val
    request['params'] = p
  requests[method].append(request)

# %% [markdown]
# ## Shorten URI

# %%
for method in requests:
  method_requests = requests[method]
  for request in method_requests:
    words = request['uri'].split('/')
    if len(words) > 2:
      end = words[-1]
      if '.' in end:
        request['uri'] = request['uri'][:len(request['uri'])-len(end)]

# %%
requests
# Out:
# {'GET': [{'params': {'1635100342': None},
#    'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'0.2.0': None},
#    'uri': '/media/vendor/joomla-custom-elements/css/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'function': 'jSelectMenu_jform_params_customRegLinkMenu',
#     'layout': 'modal',
#     'option': 'com_menus',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php'},
#   {'params': {'Itemid': '101',
#     'id': '16',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHAvY29tcG9uZW50L3VzZXJzL2xvZ2luP0l0ZW1pZD0xMDE%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'cf6e1c019dfc542b9b8a481f01d53f09': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'37c5f2d68d971312b4cd5bd42cc0c18e': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'Itemid': '101',
#     'id': '16',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC8%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'top-a',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'1.1.5': None}, 'uri': '/media/vendor/awesomplete/css/'},
#   {'params': {'a8e69811d5b82f84ca0384ee19e93e02': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'footer',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'faea9ca18e3e92a6243f66d83d5ff12f01b925bc': None},
#    'uri': '/media/system/js/'},
#   {'params': {'Itemid': '101', 'task': 'profile.edit', 'user_id': '365'},
#    'uri': '/index.php/component/users/'},
#   {'params': {'Itemid': '101', 'id': '17', 'return': None, 'view': 'modules'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'bae2911b22f836c780af199d956a1b22c8604694': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'Itemid': '101',
#     'id': '1',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC8%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'function': 'jSelectMenu_jform_params_login',
#     'layout': 'modal',
#     'option': 'com_menus',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php'},
#   {'params': {'20a3e3a58f848a8275447c7750a2afe0': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'search',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'62cd2c5719d18425a0f3e964eda5e656': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'layout': 'default', 'view': 'setup'}, 'uri': '/installation/'},
#   {'params': {'b1f2785ddb720f6641d3a357aaa4e59c': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'4a0316c0aa05352ee7be88bcaa27e66c': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/templates/cassiopeia/css/system/searchtools/'},
#   {'params': {'Itemid': '101',
#     'id': '16',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHAvY29tcG9uZW50L3VzZXJzL3Byb2ZpbGU%2FdXNlcl9pZD04NjEmSXRlbWlkPTEwMQ%3D%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'Itemid': '101'}, 'uri': '/index.php/component/users/profile'},
#   {'uri': '/installation/template/images/'},
#   {'params': {'30d60475f546daa706ad6d1915d82554': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'breadcrumbs',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'Itemid': '101', 'id': '16', 'return': None, 'view': 'modules'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'5.1.2': None}, 'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'Itemid': '101', 'user_id': '861'},
#    'uri': '/index.php/component/users/profile'},
#   {'params': {'b1f2785ddb720f6641d3a357aaa4e59c': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'function': 'jSelectMenu_jform_params_base',
#     'layout': 'modal',
#     'option': 'com_menus',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php'},
#   {'params': {'30d60475f546daa706ad6d1915d82554': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'uri': '/media/vendor/joomla-custom-elements/css/'},
#   {'params': {'edf5da158494aa612a289c1342674ce5': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'Itemid': '101'}, 'uri': '/index.php/component/users/login'},
#   {'params': {'30d60475f546daa706ad6d1915d82554': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': None},
#    'uri': '/media/system/js/fields/calendar-locales/date/gregorian/'},
#   {'params': {'a969c55130034e00a01d7a61cf17ff60': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'uri': '/installation/template/images/'},
#   {'params': {'ae479c3ec9ebdd2d4ce697834f8000e5': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'a8e69811d5b82f84ca0384ee19e93e02': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'a90ef4d0272b7d3c6bf455f88d48ef92': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'Itemid': '101',
#     'id': '1',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHAvY29tcG9uZW50L3VzZXJzL2xvZ2luP0l0ZW1pZD0xMDE%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'62cd2c5719d18425a0f3e964eda5e656': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'90f803363f74b2a8d2269e0a941f49fb294521b5': None},
#    'uri': '/media/system/js/'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': None},
#    'uri': '/templates/cassiopeia/js/'},
#   {'params': {'f76614a44039e2bb5becacfb081df5bf015b351d': None},
#    'uri': '/media/system/js/'},
#   {'params': {'Itemid': '101', 'id': '1', 'return': None, 'view': 'modules'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'a969c55130034e00a01d7a61cf17ff60': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'footer',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'1635100342': None}, 'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'4a0316c0aa05352ee7be88bcaa27e66c': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'Itemid': '101'}, 'uri': '/index.php/component/users/remind'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'ae479c3ec9ebdd2d4ce697834f8000e5': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'breadcrumbs',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'a8e69811d5b82f84ca0384ee19e93e02': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'search',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'Itemid': '101', 'id': '17', 'return': None, 'view': 'modules'},
#    'uri': '/index.php/component/config/'},
#   {'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'852c3c99beb07406033f85429263d74798ef3b15': None},
#    'uri': '/media/system/css/fields/'},
#   {'params': {'Itemid': '101',
#     'id': '17',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%2Fb3B0aW9uPWNvbV9jb25maWcmdmlldz1tb2R1bGVzJmlkPTEmSXRlbWlkPTEwMSZyZXR1cm49YUhSMGNEb3ZMMnh2WTJGc2FHOXpkQzglM0Q%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'uri': '/media/vendor/fontawesome-free/webfonts/'},
#   {'params': {'5.1.2': None}, 'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'Itemid': '101', 'layout': 'edit'},
#    'uri': '/index.php/component/users/profile'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'breadcrumbs',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'a8e69811d5b82f84ca0384ee19e93e02': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'below-top',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/templates/cassiopeia/css/global/'},
#   {'params': {'20ace83a13886af1b0b5f58386fd8adf33f586a3': None},
#    'uri': '/media/system/js/'},
#   {'params': {'Itemid': '101',
#     'id': '17',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%2Fb3B0aW9uPWNvbV9jb25maWcmdmlldz1tb2R1bGVzJmlkPTE3Jkl0ZW1pZD0xMDEmcmV0dXJuPWFIUjBjRG92TDJ4dlkyRnNhRzl6ZEM5cGJtUmxlQzV3YUhBJTNE',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'Itemid': '101',
#     'id': '16',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'breadcrumbs',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'ae479c3ec9ebdd2d4ce697834f8000e5': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'uri': '/'},
#   {'params': {'a8d4570ab9e3ccadeed67333e580785a': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'20a3e3a58f848a8275447c7750a2afe0': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'Itemid': '101',
#     'id': '16',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%...%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'0.2.0': None},
#    'uri': '/templates/cassiopeia/css/vendor/joomla-custom-elements/'},
#   {'uri': '/templates/cassiopeia/css/global/'},
#   {'params': {'37c5f2d68d971312b4cd5bd42cc0c18e': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'829f461d24cbeee7c3f0bd47bf458ad3d128d3cf': None},
#    'uri': '/media/com_users/js/'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/media/system/js/fields/calendar-locales/date/gregorian/'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': None},
#    'uri': '/templates/cassiopeia/css/global/'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/media/plg_user_token/js/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'top-a',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'310d8eb8f7b2eeb6f82c417fe1d24271e32a8d95': None},
#    'uri': '/media/system/css/fields/'},
#   {'params': {'Itemid': '101',
#     'id': '17',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHAvY29tcG9uZW50L3VzZXJzL2xvZ2luP0l0ZW1pZD0xMDE%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'035512da5c398e330c2281a95ae79a9140018b48': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'5.1.2': None}, 'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/media/system/css/'},
#   {'params': {'Itemid': '101',
#     'id': '1',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'1635100342': None}, 'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'20a3e3a58f848a8275447c7750a2afe0': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': None},
#    'uri': '/templates/cassiopeia/css/'},
#   {'params': {'a969c55130034e00a01d7a61cf17ff60': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'a8d4570ab9e3ccadeed67333e580785a': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'21cc9d15d26f5ab835adef2608fc8abf050422d0': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'edf5da158494aa612a289c1342674ce5': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'edf5da158494aa612a289c1342674ce5': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'Itemid': '101',
#     'id': '17',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%%3D%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'uri': '/templates/cassiopeia/images/'},
#   {'uri': '/templates/cassiopeia/images/'},
#   {'params': {'cf6e1c019dfc542b9b8a481f01d53f09': None},
#    'uri': '/installation/template/css/'},
#   {'uri': '/media/system/images/'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/templates/cassiopeia/js/'},
#   {'params': {'Itemid': '101', 'task': 'profile.edit', 'user_id': '861'},
#    'uri': '/index.php/component/users/'},
#   {'params': {'a90ef4d0272b7d3c6bf455f88d48ef92': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'1.1.5': None}, 'uri': '/media/vendor/awesomplete/js/'},
#   {'params': {'a8e69811d5b82f84ca0384ee19e93e02': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'banner',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'4a0316c0aa05352ee7be88bcaa27e66c': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'cf6e1c019dfc542b9b8a481f01d53f09': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'Itemid': '101',
#     'id': '16',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%2Fb3B0aW9uPWNvbV9jb25maWcmdmlldz1tb2R1bGVzJmlkPTEmSXRlbWlkPTEwMSZyZXR1cm49YUhSMGNEb3ZMMnh2WTJGc2FHOXpkQzlwYm1SbGVDNXdhSEElM0Q%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'uri': '/media/system/images/'},
#   {'params': {'layout': 'default', 'view': 'remove'}, 'uri': '/installation/'},
#   {'params': {'Itemid': '101',
#     'id': '1',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%2Fb3B0aW9uPWNvbV9jb25maWcmdmlldz1tb2R1bGVzJmlkPTE3Jkl0ZW1pZD0xMDEmcmV0dXJuPWFIUjBjRG92TDJ4dlkyRnNhRzl6ZEM5cGJtUmxlQzV3YUhBJTNE',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'17121a112ecec3d656efe5c5f493429c9acf2179': None},
#    'uri': '/media/system/js/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'banner',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'Itemid': '101',
#     'id': '1',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'uri': '/installation/template/images/'},
#   {'params': {'b1f2785ddb720f6641d3a357aaa4e59c': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'Itemid': '101', 'id': '16', 'return': None, 'view': 'modules'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'a90ef4d0272b7d3c6bf455f88d48ef92': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'9.0.1': None},
#    'uri': '/templates/cassiopeia/css/vendor/choicesjs/'},
#   {'params': {'Itemid': '101',
#     'id': '17',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC8%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'a8e69811d5b82f84ca0384ee19e93e02': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'cb7f653c510ddb6c629382e0e62b733f0f9487fa': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'a8e69811d5b82f84ca0384ee19e93e02': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'breadcrumbs',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'params': {'Itemid': '101',
#     'id': '1',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'Itemid': '101',
#     'id': '1',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%...',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': None},
#    'uri': '/templates/cassiopeia/css/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'Itemid': '101',
#     'layout': 'modal',
#     'menutype': 'mainmenu',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php/component/menus/'},
#   {'params': {'98c7f2f8860f0c44d72a82d32ed191007007de67': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'Itemid': '101',
#     'id': '17',
#     'option': 'com_config',
#     'return': 'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%3D',
#     'view': 'modules'},
#    'uri': '/index.php'},
#   {'params': {'a1e461344086554012c3f7b55cb470b5b7352dc9': None},
#    'uri': '/media/com_config/js/'},
#   {'params': {'37c5f2d68d971312b4cd5bd42cc0c18e': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'7425e8d1cb9e4f061d5e30271d6d99b085344117': None},
#    'uri': '/media/system/js/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'function': 'jSelectMenu_jform_params_logout',
#     'layout': 'modal',
#     'option': 'com_menus',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php'},
#   {'uri': '/media/system/css/'},
#   {'params': {'fa07915783bd748acde8a86b470018eb': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'2cf5ce06b5b33eeae7bfc9c13af12daa32ce7475': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'50351965a24162f3a5ad18e845e2185d': None},
#    'uri': '/installation/template/css/'},
#   {'params': {'9.0.1': None}, 'uri': '/media/vendor/choicesjs/js/'},
#   {'params': {'a969c55130034e00a01d7a61cf17ff60': '1',
#     'client_id': '0',
#     'module_id': '1',
#     'option': 'com_modules',
#     'position': 'sidebar-right',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'fa07915783bd748acde8a86b470018eb': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'50351965a24162f3a5ad18e845e2185d': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'50351965a24162f3a5ad18e845e2185d': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'Itemid': '101', 'user_id': '365'},
#    'uri': '/index.php/component/users/profile'},
#   {'params': {'Itemid': '101', 'layout': 'edit', 'user_id': '861'},
#    'uri': '/index.php/component/users/profile'},
#   {'params': {'9fd9966464a66118f626e9e3ae70fa2408d12238': None},
#    'uri': '/media/com_menus/js/'},
#   {'params': {'62cd2c5719d18425a0f3e964eda5e656': None},
#    'uri': '/installation/template/js/'},
#   {'uri': '/index.php'},
#   {'params': {'a969c55130034e00a01d7a61cf17ff60': '1',
#     'client_id': '0',
#     'function': 'jSelectMenu_jform_params_base',
#     'layout': 'modal',
#     'option': 'com_menus',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php'},
#   {'params': {'fa07915783bd748acde8a86b470018eb': None},
#    'uri': '/installation/template/js/'},
#   {'params': {'Itemid': '101'}, 'uri': '/index.php/component/users/reset'},
#   {'params': {'a969c55130034e00a01d7a61cf17ff60': '1',
#     'client_id': '0',
#     'module_id': '17',
#     'option': 'com_modules',
#     'position': 'breadcrumbs',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php'},
#   {'uri': '/templates/cassiopeia/css/'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': None},
#    'uri': '/media/system/css/'},
#   {'params': {'a8d4570ab9e3ccadeed67333e580785a': None},
#    'uri': '/installation/template/js/'},
#   {'uri': '/templates/cassiopeia/js/'},
#   {'params': {'Itemid': '101',
#     'a969c55130034e00a01d7a61cf17ff60': '1',
#     'layout': 'modal',
#     'menutype': 'mainmenu',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php/component/menus/'},
#   {'params': {'9f7b2a63e13eada7a02ec80fcdd81817627851ae': None},
#    'uri': '/media/system/js/fields/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'client_id': '0',
#     'module_id': '16',
#     'option': 'com_modules',
#     'position': 'banner',
#     'task': 'module.orderPosition'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': None},
#    'uri': '/templates/cassiopeia/css/system/searchtools/'},
#   {'uri': '/installation/'},
#   {'uri': '/installation/'}],
#  'POST': [{'params': {'format': 'json', 'task': 'installation.config'},
#    'uri': '/installation/'},
#   {'params': {'Itemid': '101', 'task': 'user.login'},
#    'uri': '/index.php/component/users/'},
#   {'params': {'format': 'json', 'task': 'installation.dbcheck'},
#    'uri': '/installation/'},
#   {'params': {'format': 'json', 'task': 'installation.populate3'},
#    'uri': '/installation/'},
#   {'params': {'Itemid': '101', 'task': 'reset.request'},
#    'uri': '/index.php/component/users/'},
#   {'params': {'a969c55130034e00a01d7a61cf17ff60': '1',
#     'layout': 'modal',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php/component/menus/'},
#   {'params': {'format': 'json', 'task': 'installation.removeFolder'},
#    'uri': '/installation/'},
#   {'params': {'format': 'json', 'task': 'installation.custom1'},
#    'uri': '/installation/'},
#   {'params': {'3739c4e9aad6e1d60e964c728efa6c17': '1',
#     'layout': 'modal',
#     'tmpl': 'component',
#     'view': 'items'},
#    'uri': '/index.php/component/menus/'},
#   {'params': {'Itemid': '101'}, 'uri': '/index.php/component/users/reset'},
#   {'params': {'Itemid': '101'}, 'uri': '/index.php/component/users/login'},
#   {'uri': '/installation/'},
#   {'uri': '/index.php'},
#   {'params': {'administratorlang': 'en-US',
#     'format': 'json',
#     'frontendlang': 'en-US',
#     'task': 'language.setdefault',
#     'view': 'setup'},
#    'uri': '/installation/'},
#   {'params': {'format': 'json', 'task': 'installation.populate2'},
#    'uri': '/installation/'},
#   {'params': {'format': 'json'}, 'uri': '/index.php/component/ajax/'},
#   {'params': {'Itemid': '101', 'view': 'featured'},
#    'uri': '/index.php/component/config/'},
#   {'params': {'format': 'json', 'task': 'installation.create'},
#    'uri': '/installation/'},
#   {'params': {'format': 'json', 'task': 'installation.populate1'},
#    'uri': '/installation/'},
#   {'params': {'format': 'json', 'task': 'installation.languages'},
#    'uri': '/installation/'},
#   {'params': {'Itemid': '101', 'task': 'remind.remind'},
#    'uri': '/index.php/component/users/'},
#   {'params': {'Itemid': '101', 'view': 'featured'},
#    'uri': '/index.php/component/users/'},
#   {'params': {'format': 'json', 'task': 'installation.custom2'},
#    'uri': '/installation/'}]}

# %% [markdown]
# ## Merge requests that have same URI

# %%
def merge_requests(requests):
  # print(requests[0]['uri'])
  # print(len(requests))
  new_request = {}
  new_request['uri'] = requests[0]['uri']
  # print(requests[0])
  params = {}
  
  for request in requests:
    if 'params' in request:
      for p in request['params']:
        value = request['params'][p]
      
        if p not in params:
          params[p] = [value]
        else: 
          params[p].append(value)
        params[p] = list(set(params[p]))
    
  new_request['params'] = params
  return new_request

# %%
def refine_request_list(requests):
  group_requests = {}
  for method in requests:
    rq_list = requests[method]
    rq_list.sort(key=lambda x: x['uri'])
    group_requests[method] = []

    i = 0
    same_uri = []
    while i < len(rq_list):
      if len(same_uri) == 0:
        same_uri = [rq_list[i]]

      if i < len(rq_list) - 1 and rq_list[i]['uri'] in rq_list[i+1]['uri'] and rq_list[i]['uri'] != '/':
        same_uri.append(rq_list[i+1])
        rq_list.remove(rq_list[i+1])
        continue
      else:
        request = merge_requests(same_uri)
        group_requests[method].append(request)
        same_uri = []
      
      i += 1  
  return group_requests

# %%
group_requests = refine_request_list(requests)

# %%
group_requests
# Out:
# {'GET': [{'params': {}, 'uri': '/'},
#   {'params': {'30d60475f546daa706ad6d1915d82554': ['1'],
#     '3739c4e9aad6e1d60e964c728efa6c17': ['1'],
#     'Itemid': ['101'],
#     'a8e69811d5b82f84ca0384ee19e93e02': ['1'],
#     'a969c55130034e00a01d7a61cf17ff60': ['1'],
#     'ae479c3ec9ebdd2d4ce697834f8000e5': ['1'],
#     'client_id': ['0'],
#     'function': ['jSelectMenu_jform_params_logout',
#      'jSelectMenu_jform_params_login',
#      'jSelectMenu_jform_params_customRegLinkMenu',
#      'jSelectMenu_jform_params_base'],
#     'id': ['17', '16', '1'],
#     'layout': ['modal', 'edit'],
#     'menutype': ['mainmenu'],
#     'module_id': ['17', '16', '1'],
#     'option': ['com_config', 'com_menus', 'com_modules'],
#     'position': ['top-a',
#      'below-top',
#      'breadcrumbs',
#      'banner',
#      'footer',
#      'search',
#      'sidebar-right'],
#     'return': ['aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%...',
#      'aHR0cDovL2xvY2FsaG9zdC8%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHAvY29tcG9uZW50L3VzZXJzL2xvZ2luP0l0ZW1pZD0xMDE%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%2Fb3B0aW9uPWNvbV9jb25maWcmdmlldz1tb2R1bGVzJmlkPTEmSXRlbWlkPTEwMSZyZXR1cm49YUhSMGNEb3ZMMnh2WTJGc2FHOXpkQzlwYm1SbGVDNXdhSEElM0Q%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%%3D%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHAvY29tcG9uZW50L3VzZXJzL3Byb2ZpbGU%2FdXNlcl9pZD04NjEmSXRlbWlkPTEwMQ%3D%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%2Fb3B0aW9uPWNvbV9jb25maWcmdmlldz1tb2R1bGVzJmlkPTEmSXRlbWlkPTEwMSZyZXR1cm49YUhSMGNEb3ZMMnh2WTJGc2FHOXpkQzglM0Q%3D',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%2Fb3B0aW9uPWNvbV9jb25maWcmdmlldz1tb2R1bGVzJmlkPTE3Jkl0ZW1pZD0xMDEmcmV0dXJuPWFIUjBjRG92TDJ4dlkyRnNhRzl6ZEM5cGJtUmxlQzV3YUhBJTNE',
#      'aHR0cDovL2xvY2FsaG9zdC9pbmRleC5waHA%...%3D',
#      None],
#     'task': ['module.orderPosition', 'profile.edit'],
#     'tmpl': ['component'],
#     'user_id': ['365', '861'],
#     'view': ['items', 'modules']},
#    'uri': '/index.php'},
#   {'params': {'20a3e3a58f848a8275447c7750a2afe0': [None],
#     '37c5f2d68d971312b4cd5bd42cc0c18e': [None],
#     '4a0316c0aa05352ee7be88bcaa27e66c': [None],
#     '50351965a24162f3a5ad18e845e2185d': [None],
#     '62cd2c5719d18425a0f3e964eda5e656': [None],
#     'a8d4570ab9e3ccadeed67333e580785a': [None],
#     'a90ef4d0272b7d3c6bf455f88d48ef92': [None],
#     'b1f2785ddb720f6641d3a357aaa4e59c': [None],
#     'cf6e1c019dfc542b9b8a481f01d53f09': [None],
#     'edf5da158494aa612a289c1342674ce5': [None],
#     'fa07915783bd748acde8a86b470018eb': [None],
#     'layout': ['default'],
#     'view': ['setup', 'remove']},
#    'uri': '/installation/'},
#   {'params': {'a1e461344086554012c3f7b55cb470b5b7352dc9': [None]},
#    'uri': '/media/com_config/js/'},
#   {'params': {'9fd9966464a66118f626e9e3ae70fa2408d12238': [None]},
#    'uri': '/media/com_menus/js/'},
#   {'params': {'829f461d24cbeee7c3f0bd47bf458ad3d128d3cf': [None]},
#    'uri': '/media/com_users/js/'},
#   {'params': {'ce6270fd318f821b946b987d392416a6': [None]},
#    'uri': '/media/plg_user_token/js/'},
#   {'params': {'310d8eb8f7b2eeb6f82c417fe1d24271e32a8d95': [None],
#     '852c3c99beb07406033f85429263d74798ef3b15': [None],
#     'a2b2b46c812fbb16f34e65832fbbe2b6': [None],
#     'ce6270fd318f821b946b987d392416a6': [None]},
#    'uri': '/media/system/css/'},
#   {'params': {}, 'uri': '/media/system/images/'},
#   {'params': {'035512da5c398e330c2281a95ae79a9140018b48': [None],
#     '17121a112ecec3d656efe5c5f493429c9acf2179': [None],
#     '20ace83a13886af1b0b5f58386fd8adf33f586a3': [None],
#     '21cc9d15d26f5ab835adef2608fc8abf050422d0': [None],
#     '2cf5ce06b5b33eeae7bfc9c13af12daa32ce7475': [None],
#     '7425e8d1cb9e4f061d5e30271d6d99b085344117': [None],
#     '90f803363f74b2a8d2269e0a941f49fb294521b5': [None],
#     '98c7f2f8860f0c44d72a82d32ed191007007de67': [None],
#     '9f7b2a63e13eada7a02ec80fcdd81817627851ae': [None],
#     'a2b2b46c812fbb16f34e65832fbbe2b6': [None],
#     'bae2911b22f836c780af199d956a1b22c8604694': [None],
#     'cb7f653c510ddb6c629382e0e62b733f0f9487fa': [None],
#     'ce6270fd318f821b946b987d392416a6': [None],
#     'f76614a44039e2bb5becacfb081df5bf015b351d': [None],
#     'faea9ca18e3e92a6243f66d83d5ff12f01b925bc': [None]},
#    'uri': '/media/system/js/'},
#   {'params': {'1.1.5': [None]}, 'uri': '/media/vendor/awesomplete/css/'},
#   {'params': {'1.1.5': [None]}, 'uri': '/media/vendor/awesomplete/js/'},
#   {'params': {'1635100342': [None], '5.1.2': [None]},
#    'uri': '/media/vendor/bootstrap/js/'},
#   {'params': {'9.0.1': [None]}, 'uri': '/media/vendor/choicesjs/js/'},
#   {'params': {}, 'uri': '/media/vendor/fontawesome-free/webfonts/'},
#   {'params': {'0.2.0': [None]},
#    'uri': '/media/vendor/joomla-custom-elements/css/'},
#   {'params': {'0.2.0': [None],
#     '9.0.1': [None],
#     'a2b2b46c812fbb16f34e65832fbbe2b6': [None],
#     'ce6270fd318f821b946b987d392416a6': [None]},
#    'uri': '/templates/cassiopeia/css/'},
#   {'params': {}, 'uri': '/templates/cassiopeia/images/'},
#   {'params': {'a2b2b46c812fbb16f34e65832fbbe2b6': [None],
#     'ce6270fd318f821b946b987d392416a6': [None]},
#    'uri': '/templates/cassiopeia/js/'}],
#  'POST': [{'params': {'3739c4e9aad6e1d60e964c728efa6c17': ['1'],
#     'Itemid': ['101'],
#     'a969c55130034e00a01d7a61cf17ff60': ['1'],
#     'format': ['json'],
#     'layout': ['modal'],
#     'task': ['reset.request', 'remind.remind', 'user.login'],
#     'tmpl': ['component'],
#     'view': ['items', 'featured']},
#    'uri': '/index.php'},
#   {'params': {'administratorlang': ['en-US'],
#     'format': ['json'],
#     'frontendlang': ['en-US'],
#     'task': ['installation.removeFolder',
#      'installation.create',
#      'installation.custom2',
#      'installation.config',
#      'installation.populate1',
#      'installation.custom1',
#      'installation.populate2',
#      'installation.languages',
#      'installation.dbcheck',
#      'language.setdefault',
#      'installation.populate3'],
#     'view': ['setup']},
#    'uri': '/installation/'}]}

# %% [markdown]
# ## Generalize parameters values

# %%
for method in group_requests:
  requests = group_requests[method]
  for request in requests:
    for param in request['params']:
      list_value = request['params'][param]
      check_digit = True
      if list_value is not None:
        for value in list_value:
          if value is None or not value.isdigit():
            check_digit = False
            break
        if check_digit:
          request['params'][param] = ["^[0-9]*$"]

# %% [markdown]
# ## Format rules

# %%
rules = []
for method in group_requests:
  requests = group_requests[method]
  for request in requests:
    rule = request
    rule['method'] = method
    rules.append(rule)

# %%
with open('rules.json', 'w') as f:
  json.dump(rules, f)

# %% [markdown]
# ## Update rules based on new requests

# %%
convert_to_json('new_log.log', 'new_log.json')

# %%
def check_request(request, rules):
  for rule in rules:
    if request['method'] == rule['method'] and rule['uri'] in request['uri']:
        request_params = request['params']
        params = rule['params']
        if(len(request_params) == 0):
          break
        elif(len(params) == 0):
          return = False
          break
        else:
          for p in request_params:
            if p not in params or request_params[p] not in params[p]:
              return False
        return True
    return False

# %%
with open('rules.json', 'r') as f:
  rules = json.load(f)
with open('new_log.json', 'r') as f:
  new_log = json.load(f)
